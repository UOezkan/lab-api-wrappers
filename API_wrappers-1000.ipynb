# %% [markdown]
# 10k Songs & Adding Audio | Spotify Connection

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /opt/anaconda3/lib/python3.11/site-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in /opt/anaconda3/lib/python3.11/site-packages (from spotipy) (5.0.4)
# Requirement already satisfied: requests>=2.25.0 in /opt/anaconda3/lib/python3.11/site-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in /opt/anaconda3/lib/python3.11/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.11/site-packages (from spotipy) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->spotipy) (2024.2.2)

# %%
import pandas as pd
from pandas import json_normalize

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

from random import randint
from time import sleep

# %%
pd.set_option("display.max_columns", 0)

# %%
secrets_file = open("secrets1.txt","r")

# %% [markdown]
# Spotify Connection

# %%
string = secrets_file.read()

# %%
string
# Out:
# 'clientid:ad6becd2bbb14a27ab52a381a9dd9b69\nclientsecret:d7fcf66c4ea241aa958d81cc53c41063'

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
secrets_dict
# Out:
# {'clientid': 'ad6becd2bbb14a27ab52a381a9dd9b69',
#  'clientsecret': 'd7fcf66c4ea241aa958d81cc53c41063'}

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %% [markdown]
# Top-1000-Playlist

# %%
def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
all_tracks = get_playlist_tracks("2LOxEzC4KmoWJ9NhW0kz5M")
# https://open.spotify.com/playlist/2LOxEzC4KmoWJ9NhW0kz5M
# all_tracks = sp.user_playlist_tracks("spotify", "2LOxEzC4KmoWJ9NhW0kz5M")

# %%
len(all_tracks)
# Out:
# 992

# %%
tracks = json_normalize(all_tracks)

# %%
artists_df = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify','song_id', 'song_name', 'popularity' ])
for i in tracks.index:
    artists_for_song = json_normalize(tracks.iloc[i]['track.artists'])
    artists_for_song['song_id']    = tracks.iloc[i]['track.id']         # we want to keep song_id, it is the sae for all artists
    artists_for_song['song_name']  = tracks.iloc[i]['track.name']       # we want to keep song_name, it is the sae for all artists
    artists_for_song['popularity'] = tracks.iloc[i]['track.popularity'] # same for popularity   
    artists_df = pd.concat([artists_df, artists_for_song], axis=0)

# %%
artists_df.head()
# Out:
#                                                 href  ... popularity
# 0  https://api.spotify.com/v1/artists/1dfeR4HaWDb...  ...          0
# 0  https://api.spotify.com/v1/artists/3qm84nBOXUE...  ...          9
# 0  https://api.spotify.com/v1/artists/6olE6TJLqED...  ...          2
# 0  https://api.spotify.com/v1/artists/4x1nvY2FN8j...  ...         76
# 0  https://api.spotify.com/v1/artists/1QxaPWG1POM...  ...         60
#
# [5 rows x 9 columns]

# %%
df_final = artists_df[['song_name', 'name', 'song_id', 'popularity']].reset_index(drop=True)
df_final
# Out:
#                                               song_name  ... popularity
# 0                   Bohemian Rhapsody - Remastered 2011  ...          0
# 1                                   Sweet Child O' Mine  ...          9
# 2                               Smells Like Teen Spirit  ...          2
# 3                             Imagine - Remastered 2010  ...         76
# 4                                      You're the Voice  ...         60
# ...                                                 ...  ...        ...
# 1063                                   Running on Empty  ...          0
# 1064  Every Little Thing She Does Is Magic - Remaste...  ...          0
# 1065                               Doo Wop (That Thing)  ...          0
# 1066                          The Boys Are Back In Town  ...         74
# 1067                                             Desire  ...         61
#
# [1068 rows x 4 columns]

# %%
df_final.isna().sum()
#drop the rows with null values in song_id due to not to extract song features for them
# Out:
# song_name     0
# name          0
# song_id       0
# popularity    0
# dtype: int64

# %%
df_final2=df_final.dropna()
df_final2
# Out:
#                                               song_name  ... popularity
# 0                   Bohemian Rhapsody - Remastered 2011  ...          0
# 1                                   Sweet Child O' Mine  ...          9
# 2                               Smells Like Teen Spirit  ...          2
# 3                             Imagine - Remastered 2010  ...         76
# 4                                      You're the Voice  ...         60
# ...                                                 ...  ...        ...
# 1063                                   Running on Empty  ...          0
# 1064  Every Little Thing She Does Is Magic - Remaste...  ...          0
# 1065                               Doo Wop (That Thing)  ...          0
# 1066                          The Boys Are Back In Town  ...         74
# 1067                                             Desire  ...         61
#
# [1068 rows x 4 columns]

# %% [markdown]
# Audio Features

# %%
chunks = [(i, i+100) for i in range(0, len(df_final), 100)]
chunks  #produces a list of tuples
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final['song_id'][chunk[0]:chunk[1]]   #chunk[0]= first number of the tuple, chunk[1]= second number
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)

# %%
audio_features_df = json_normalize(audio_features_list)
audio_features_df
# Out:
#       danceability  energy  ...  duration_ms  time_signature
# 0            0.414   0.404  ...       354320               4
# 1            0.454   0.910  ...       354520               4
# 2            0.502   0.912  ...       301920               4
# 3            0.547   0.257  ...       187867               4
# 4            0.369   0.762  ...       302107               4
# ...            ...     ...  ...          ...             ...
# 1063         0.531   0.948  ...       298093               4
# 1064         0.535   0.745  ...       260573               4
# 1065         0.535   0.505  ...       320267               4
# 1066         0.445   0.706  ...       266720               4
# 1067         0.490   0.827  ...       179360               4
#
# [1068 rows x 18 columns]

# %%
audio_features_df.drop_duplicates(inplace=True) # duplicates because some songs have more artists
audio_features_df.shape
# Out:
# (992, 18)

# %% [markdown]
# Concatenating the songs with their audio features and exporting the df in a csv file

# %%
df_w_audio_ft = pd.merge(left=df_final, right=audio_features_df, how='inner', left_on='song_id',right_on='id')
df_w_audio_ft
# Out:
#                                               song_name  ... time_signature
# 0                   Bohemian Rhapsody - Remastered 2011  ...              4
# 1                                   Sweet Child O' Mine  ...              4
# 2                               Smells Like Teen Spirit  ...              4
# 3                             Imagine - Remastered 2010  ...              4
# 4                                      You're the Voice  ...              4
# ...                                                 ...  ...            ...
# 1063                                   Running on Empty  ...              4
# 1064  Every Little Thing She Does Is Magic - Remaste...  ...              4
# 1065                               Doo Wop (That Thing)  ...              4
# 1066                          The Boys Are Back In Town  ...              4
# 1067                                             Desire  ...              4
#
# [1068 rows x 22 columns]

# %%
df_w_audio_ft.to_csv('top_992_songs.csv', index=False)
